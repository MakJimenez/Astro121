# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Plotting data 

importdata = np.load("testfreq1420.npz")
indexdata = importdata["arr_1"]
print(importdata["arr_0"])
data = indexdata[3]

# Convert I/Q to complex data
complexdata = data[:,0] + 1j * data[:,1]

# FFT Parameters 
sampling_rate = 2.9e6
N = len(complexdata)

# Hann window + FFT
window = np.hanning(N)
fft_data = np.fft.fftshift(np.fft.fft(complexdata * window))

# Power Spectrum
power = np.abs(fft_data)**2
power_db = 10 * np.log10(power)

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))

# Plotting
plt.figure(figsize=(10, 4))
plt.plot(f / 1e3, power_db)
plt.axvline(-155, linestyle=":", color="black", linewidth=2) # expected signal location
plt.yscale("log")
plt.xlim(-156, -154)
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
plt.title("Basebamd Power Spectrum (I/Q Data, Hann Window)")
plt.grid(True)
plt.show()
# Out:
# ['File:testfreq1420' 'Frequency:1420 MHz' 'Amplitude:-30 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771301324.7836359'
#  'Local: Mon Feb 16 20:08:44 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: gain = 3']

# %%
# Plotting data 

importdata = np.load("testfreq1420_2.npz")
indexdata = importdata["arr_1"]
print(importdata["arr_0"])
data = indexdata[3]

# Convert I/Q to complex data
complexdata = data[:,0] + 1j * data[:,1]

# FFT Parameters 
sampling_rate = 2.9e6
N = len(complexdata)

# Hann window + FFT
window = np.hanning(N)
fft_data = np.fft.fftshift(np.fft.fft(complexdata * window))

# Power Spectrum
power = np.abs(fft_data)**2
power_db = 10 * np.log10(power)

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))

# Plotting
plt.figure(figsize=(10, 4))
plt.plot(f / 1e3, power_db)
plt.axvline(-10, linestyle=":", color="black", linewidth=2) # expected signal location
plt.yscale("log")
# plt.xlim(-50, 50)
# plt.xlim()
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
plt.title("Basebamd Power Spectrum (I/Q Data, Hann Window)")
plt.grid(True)
plt.show()
# Out:
# ['File:testfreq1420_2' 'Frequency:1420 MHz' 'Amplitude:20 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771302390.482395'
#  'Local: Mon Feb 16 20:26:30 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Cranking the amplitude up in hopes of something']

# %%
# Hell yeah brother. Cranked up the amplitdue to 20 dB, gain =3, no attenuators

# %%
# Moving the amplitude to zero dBm

# Plotting data 

importdata = np.load("freq1420.npz")
indexdata = importdata["arr_1"]
print(importdata["arr_0"])
data = indexdata[3]

# Convert I/Q to complex data
complexdata = data[:,0] + 1j * data[:,1]

# FFT Parameters 
sampling_rate = 2.9e6
N = len(complexdata)

# Hann window + FFT
window = np.hanning(N)
fft_data = np.fft.fftshift(np.fft.fft(complexdata * window))

# Power Spectrum
power = np.abs(fft_data)**2
power_db = 10 * np.log10(power)

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))

# Plotting
plt.figure(figsize=(10, 4))
plt.axvline(10, linestyle=":", color="black", linewidth=2) # expected signal location
plt.plot(f / 1e3, power_db)
plt.xlim(-200, 200)
# plt.xlim()
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
plt.title("Basebamd Power Spectrum (I/Q Data, Hann Window)")
plt.grid(True)
plt.show()
# Out:
# ['File:freq1420' 'Frequency:1420.405 MHz' 'Amplitude:0 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771302857.524269'
#  'Local: Mon Feb 16 20:34:17 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Moving frequency to confirm we are observing the correct signal.']

# %%
# Moving the frequency to make sure this is our frequency

# %%
# amplitude to zero dBm, frequency 1420.405 MHz

# Plotting data 

importdata = np.load("freq1420.405.npz")
indexdata = importdata["arr_1"]
print(importdata["arr_0"])
data = indexdata[3]

# Convert I/Q to complex data
complexdata = data[:,0] + 1j * data[:,1]

# FFT Parameters 
sampling_rate = 2.9e6
N = len(complexdata)

# Hann window + FFT
window = np.hanning(N)
fft_data = np.fft.fftshift(np.fft.fft(complexdata * window))

# Power Spectrum
power = np.abs(fft_data)**2
power_db = 10 * np.log10(power)

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))

# Plotting
plt.figure(figsize=(10, 4))
plt.plot(f / 1e3, power_db)
plt.axvline(10, linestyle=":", color="black", linewidth=2) # expected signal location
# plt.xlim(-25, 25)
# plt.xlim()
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
plt.title("Baseband Power Spectrum (I/Q Data, Hann Window)")
plt.grid(True)
plt.show()
# Out:
# ['File:freq1420.405' 'Frequency:1420.405 MHz' 'Amplitude:0 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771302904.3707666'
#  'Local: Mon Feb 16 20:35:04 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Forgot to change the name, the previous file names freq1420 is also 1420.405 MHz. Moving frequency to confirm we are observing the correct signal.']

# %%
# Signal is confirmed to be ours. Now to work down to -80 dBm amplitude and not lose the signal.

# %%
# Averaging over all the power spectra (4) to try and reduce noise 

# amplitude to zero dBm, frequency 1420.405 MHz

# Importing data 
importdata = np.load("freq1420.405.npz")
indexdata = importdata["arr_1"]
print(importdata["arr_0"])
data = indexdata[3]

# Convert I/Q to complex data
complexdata = data[:,0] + 1j * data[:,1]

# FFT Parameters 
sampling_rate = 2.9e6
N = len(complexdata)
navg = 4

# Hann window + FFT
window = np.hanning(N)
fft_data = np.fft.fftshift(np.fft.fft(complexdata * window))

# Power Spectrum
power = np.abs(fft_data)**2
power_db = 10 * np.log10(power)

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))

# Loop over captures
power_accum = np.zeros(N)

for i in range(1, navg):
        d = data[i]
#         x = d[:,0] + 1j * d[:,1] # I/Q -> complex
        
        fft_data = np.fft.fftshift(np.fft.fftshift(complexdata * window))
        power_accum += np.abs(fft_data)**2

# Average + convert to dB
power_avg = power_accum / navg
power_avg_db = 10 * np.log10(power_avg)
        
# Plotting
plt.figure(figsize=(10, 4))
plt.plot(f / 1e3, power_avg_db, color="teal")
plt.axvline(10, linestyle=":", color="black", linewidth=2) # expected signal location
# plt.yscale("log")
# plt.xlim(-25, 25)
# plt.xlim()
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
plt.title(f"Baseband Power Spectrum ({navg} averages)")
plt.grid(True)
plt.show()
# Out:
# ['File:freq1420.405' 'Frequency:1420.405 MHz' 'Amplitude:0 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771302904.3707666'
#  'Local: Mon Feb 16 20:35:04 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Forgot to change the name, the previous file names freq1420 is also 1420.405 MHz. Moving frequency to confirm we are observing the correct signal.']
# /tmp/ipykernel_4936/721050210.py:42: RuntimeWarning: divide by zero encountered in log10
#   power_avg_db = 10 * np.log10(power_avg)

# %%
# Averaging over all the power spectra (4) to try and reduce noise 

# amplitude to zero dBm, frequency 1420.405 MHz

# Importing data 
importdata = np.load("freq1420.405.npz")
indexdata = importdata["arr_1"]
print(importdata["arr_0"])


# FFT Parameters 
sampling_rate = 2.9e6
navg = 4


#data, use first block to define size apparently
data0 = indexdata[3]
complex0 = data[:,0] + 1j * data[:,1]
N = len(complex0)

# Hann window + FFT
window = np.hanning(N)
power_accum = np.zeros(N)


for i in range(navg):
        data = indexdata[i]
        complexdata = data[:,0] + 1j*data[:,1]
#         x = d[:,0] + 1j * d[:,1] # I/Q -> complex
        
        fft_data = np.fft.fftshift(np.fft.fftshift(complexdata * window))
        power_accum += np.abs(fft_data)**2

# Average + convert to dB
power_avg = power_accum / navg
power_avg_db = 10 * np.log10(power_avg)

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))
        
# Plotting
plt.figure(figsize=(10, 4))
plt.plot(f / 1e3, power_avg_db, color="teal")
plt.axvline(10, linestyle=":", color="black", linewidth=2) # expected signal location
# plt.yscale("log")
# plt.xlim(-25, 25)
# plt.xlim()
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
plt.title(f"Baseband Power Spectrum ({navg} averages)")
plt.grid(True)
plt.show()
# Out:
# ['File:freq1420.405' 'Frequency:1420.405 MHz' 'Amplitude:0 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771302904.3707666'
#  'Local: Mon Feb 16 20:35:04 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Forgot to change the name, the previous file names freq1420 is also 1420.405 MHz. Moving frequency to confirm we are observing the correct signal.']
# /tmp/ipykernel_4936/1218116964.py:36: RuntimeWarning: divide by zero encountered in log10
#   power_avg_db = 10 * np.log10(power_avg)

# %%
plt.figure(figsize=(10,4))

for i in range(indexdata.shape[0]):
        data = indexdata[i]
        x = data[:,0] + 1j*data[:,1]
#         x = d[:,0] + 1j * d[:,1] # I/Q -> complex
        
        fft_data = np.fft.fftshift(np.fft.fftshift(x * window))
        power_db = 10*np.log10(np.abs(fft_data)**2)
        plt.plot(f/1e3, power_db, alpha=0.5)

plt.axvline(10, linestyle=":", color="black")
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
plt.title("Individual Block Spectra")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_4936/3761000292.py:9: RuntimeWarning: divide by zero encountered in log10
#   power_db = 10*np.log10(np.abs(fft_data)**2)

# %%
# CORRECTED AVERAGED POWER SPECTRA FOR 0 dBm
# NOISE FLOOR NOW AT -25 dBm, peak clearly visible
# fixed it so we take the log to put the y \-axis of the plot in dB scale AFETR we take the mean and average the power

import numpy as np
import matplotlib.pyplot as plt

importdata = np.load("freq1420.405.npz")
indexdata  = importdata["arr_1"]          # shape ~ (captures, samples, 2)

sampling_rate = 2.9e6                     # <-- set correctly
fLO = 1420.115e6                          # <-- if you want RF axis later (optional)

# Choose how many captures to average
M = min(50, indexdata.shape[0])           # try 50 to start

# Use the same N for every FFT
N = indexdata.shape[1]

# Window (and a normalization so power scale is consistent)
window = np.hanning(N)
W2 = np.mean(window**2)                   # window power normalization

P_accum = np.zeros(N, dtype=np.float64)

for m in range(M):
    data = indexdata[m]                   # (N,2)
    x = data[:,0] + 1j*data[:,1]          # complex IQ

    # Remove DC offset (helps a lot)
    x = x - np.mean(x)

    # FFT
    X = np.fft.fftshift(np.fft.fft(x * window))
    P = (np.abs(X)**2) / (N**2 * W2)      # linear power, normalized

    P_accum += P

P_avg = P_accum / M

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))  # Hz

# Convert to dB only at the end (add epsilon to avoid -inf)
P_avg_db = 10*np.log10(P_avg + 1e-20)

plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg_db)
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# %%
# now refine to lower dB until we reach -80 dBm with a clear spike after averaging the power

# %%
print(zenith1[1])
# Out:
# Frequency:sky Hz

# %%
# Gaussian fit with gain=3
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Noisy data collected, mixed with 600 kHz
zenithtest2 = np.load('Zenith_test2.npz')
zenith2 = zenithtest2['arr_1']

noise = (
#     N_ny_lim_600[0] + # first one is stale, makes the gaussian poke out
    zenith2[1] +
    zenith2[2] +
    zenith2[3] +
    zenith2[4] +
    zenith2[5] +
    zenith2[6] +
    zenith2[7] +
    zenith2[8] +
    zenith2[9] 
)

# Remove DC offset
noise = noise - np.mean(noise)

# RMS voltage
Vrms = np.sqrt(np.mean(noise**2))

print(f"RMS voltage = {Vrms:.3f}")

# Gaussian using RMS as sigma
mu = 0.0
sigma = Vrms

# Histogram
num_bins = 35
hist, bin_edges = np.histogram(noise, bins=num_bins, density=True)
bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])

# Gaussian
gaussian_pdf = norm.pdf(bin_centers, mu, sigma)
values, counts = np.unique(noise, return_counts=True)
pmf = counts / counts.sum()


# Plotting
plt.figure(figsize=(8, 5))
plt.plot(bin_centers, gaussian_pdf, 'teal', linewidth=3, label=r'Gaussian fit ($\sigma = V_\mathrm{RMS}$)')
plt.bar(values, pmf, width=1, alpha=0.6, color='mediumturquoise', label="Sky PMF")
plt.xlabel("Voltage")
plt.ylabel("Probability Density")
plt.title("Unfiltered Sky Data")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

from scipy.stats import kstest

ks_stat, p_value = kstest(noise, 'norm', args=(mu, sigma))

# Testing error in the Gaussian

# Mean Squared Error between histogram and Gaussian PDF
mse = np.mean((hist - gaussian_pdf)**2)
rmse = np.sqrt(mse)

print(f"MSE = {mse:.6e}")
print(f"RMSE = {rmse:.6e}")

# Known / assumed
B = 600e3  # 600 kHz

# From data
N_samples = len(noise)

# You must supply fs
fs = 1.2e6   # Hz

t = N_samples / fs

# Radiometer fractional uncertainty
frac_uncertainty = 1 / np.sqrt(B * t)

# print(f"Integration time t = {t:.3f} s")
# print(f"Fractional temperature uncertainty σT / Tsys = {frac_uncertainty:.3e}")
print(zenithtest2["arr_0"])
# Out:
# RMS voltage = 36.986
# MSE = 1.285811e-07
# RMSE = 3.585820e-04
# ['File:Zenith_test2' 'Frequency:sky Hz' 'Amplitude:0 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771366199.9668643'
#  'Local: Tue Feb 17 14:09:59 2026' 'Location: NCH' 'Direction: Zenith'
#  'Notes: Trying to find 21 cm with histogram with horn pointed at zenith.First']

# %%
np.shape(zenithtest2["arr_1"])
# Out:
# (10, 131072, 2)

# %%
# Moving onto calibrating the system on-line and off-line

# %%
# Testing OFF-LINE POWER VS IF FREQUENCY 

import numpy as np
import matplotlib.pyplot as plt

importdata = np.load("skytemp.npz")
indexdata  = importdata["arr_1"] # shape ~ (captures, samples, 2)
print(importdata["arr_0"] )

sampling_rate = 2.9e6                     # <-- set correctly
fLO = 1420.115e6                          # <-- if you want RF axis later (optional)

# Choose how many captures to average
M = min(50, indexdata.shape[0])           # try 50 to start

# Use the same N for every FFT
N = indexdata.shape[1]

# Window (and a normalization so power scale is consistent)
window = np.hanning(N)
W2 = np.mean(window**2)                   # window power normalization

P_accum = np.zeros(N, dtype=np.float64)

for m in range(M):
    data = indexdata[m]                   # (N,2)
    x = data[:,0] + 1j*data[:,1]          # complex IQ

    # Remove DC offset (helps a lot)
    x = x - np.mean(x)

    # FFT
    X = np.fft.fftshift(np.fft.fft(x * window))
    P = (np.abs(X)**2) / (N**2 * W2)      # linear power, normalized

    P_accum += P

P_avg = P_accum / M

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))  # Hz

# Convert to dB only at the end (add epsilon to avoid -inf)
P_avg_db = 10*np.log10(P_avg + 1e-20)

# Plotting 
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg, color="teal")
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# Plotting avg. power NO DB
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg_db, color="darkorchid")
# plt.plot(f/1e3, P_avg_db)
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
#plt.xlim(-500,500)
plt.title(f"Averaged Off-Line Baseband Power Spectrum (Blocks={M})")
plt.grid(True)
plt.show()
# Out:
# ['File:skytemp' 'Frequency:sky Hz' 'Amplitude:sky dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771372678.5360239'
#  'Local: Tue Feb 17 15:57:58 2026' 'Gain: 3' 'Location: NCH'
#  'Direction: Squared out on bottom West, towards SF. 7th rung from the left.'
#  'Notes: Initializing sky temp, shooting for a value of ~ 10K']

# %%
# This was with gain on 3

# %%
# Testing with no gain

# %%
# Testing OFF-LINE POWER VS IF FREQUENCY PT 2 ELECTRIC BOOGALOO

import numpy as np
import matplotlib.pyplot as plt

importdata = np.load("skytemp2.npz")
indexdata  = importdata["arr_1"]          # shape ~ (captures, samples, 2)

sampling_rate = 2.9e6                     # <-- set correctly
fLO = 1420.115e6                          # <-- if you want RF axis later (optional)

# Choose how many captures to average
M = min(50, indexdata.shape[0])           # try 50 to start

# Use the same N for every FFT
N = indexdata.shape[1]

# Window (and a normalization so power scale is consistent)
window = np.hanning(N)
W2 = np.mean(window**2)                   # window power normalization

P_accum = np.zeros(N, dtype=np.float64)

for m in range(M):
    data = indexdata[m]                   # (N,2)
    x = data[:,0] + 1j*data[:,1]          # complex IQ

    # Remove DC offset (helps a lot)
    x = x - np.mean(x)

    # FFT
    X = np.fft.fftshift(np.fft.fft(x * window))
    P = (np.abs(X)**2) / (N**2 * W2)      # linear power, normalized

    P_accum += P

P_avg = P_accum / M

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))  # Hz

# Convert to dB only at the end (add epsilon to avoid -inf)
P_avg_db = 10*np.log10(P_avg + 1e-20)

# Plotting 
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg, color="teal")
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# Plotting avg. power NO DB
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg_db, color="darkorchid")
# plt.plot(f/1e3, P_avg_db)
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# %%
# Looks like the proper off-line power vs IF freq, but super thick, not just one line

# %%
#Calibrating the system with Xavi as a blackbody

# %%
# Xavi spectrum 1 
# Testing OFF-LINE POWER VS IF FREQUENCY PT 2 ELECTRIC BOOGALOO

import numpy as np
import matplotlib.pyplot as plt

importdata = np.load("xavi_spectrum.npz")
indexdata  = importdata["arr_1"]          # shape ~ (captures, samples, 2)

sampling_rate = 2.9e6                     # <-- set correctly
fLO = 1420.115e6                          # <-- if you want RF axis later (optional)

# Choose how many captures to average
M = min(50, indexdata.shape[0])           # try 50 to start

# Use the same N for every FFT
N = indexdata.shape[1]

# Window (and a normalization so power scale is consistent)
window = np.hanning(N)
W2 = np.mean(window**2)                   # window power normalization

P_accum = np.zeros(N, dtype=np.float64)

for m in range(M):
    data = indexdata[m]                   # (N,2)
    x = data[:,0] + 1j*data[:,1]          # complex IQ

    # Remove DC offset (helps a lot)
    x = x - np.mean(x)

    # FFT
    X = np.fft.fftshift(np.fft.fft(x * window))
    P = (np.abs(X)**2) / (N**2 * W2)      # linear power, normalized

    P_accum += P

P_avg = P_accum / M

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))  # Hz

# Convert to dB only at the end (add epsilon to avoid -inf)
P_avg_db = 10*np.log10(P_avg + 1e-20)

# Plotting 
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg, color="teal")
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# Plotting avg. power NO DB
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg_db, color="darkorchid")
# plt.plot(f/1e3, P_avg_db)
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# %%
# Xavi Spectrum 2
# Testing OFF-LINE POWER VS IF FREQUENCY PT 2 ELECTRIC BOOGALOO

import numpy as np
import matplotlib.pyplot as plt

importdata = np.load("xavi_spectrum2.npz")
indexdata  = importdata["arr_1"]          # shape ~ (captures, samples, 2)

sampling_rate = 2.9e6                     # <-- set correctly
fLO = 1420.115e6                          # <-- if you want RF axis later (optional)

# Choose how many captures to average
M = min(50, indexdata.shape[0])           # try 50 to start

# Use the same N for every FFT
N = indexdata.shape[1]

# Window (and a normalization so power scale is consistent)
window = np.hanning(N)
W2 = np.mean(window**2)                   # window power normalization

P_accum = np.zeros(N, dtype=np.float64)

for m in range(M):
    data = indexdata[m]                   # (N,2)
    x = data[:,0] + 1j*data[:,1]          # complex IQ

    # Remove DC offset (helps a lot)
    x = x - np.mean(x)

    # FFT
    X = np.fft.fftshift(np.fft.fft(x * window))
    P = (np.abs(X)**2) / (N**2 * W2)      # linear power, normalized

    P_accum += P

P_avg = P_accum / M

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))  # Hz

# Convert to dB only at the end (add epsilon to avoid -inf)
P_avg_db = 10*np.log10(P_avg + 1e-20)

# Plotting 
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg, color="teal")
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (Blocks={M})")
plt.grid(True)
plt.show()

# Plotting avg. power NO DB
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg_db, color="darkorchid")
# plt.plot(f/1e3, P_avg_db)
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
# plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (Blocks={M})")
plt.grid(True)
plt.show()

# %%
# Xavi Spectrum 3 

# Testing OFF-LINE POWER VS IF FREQUENCY PT 2 ELECTRIC BOOGALOO

import numpy as np
import matplotlib.pyplot as plt

importdata = np.load("xavi_spectrum3.npz")
indexdata  = importdata["arr_1"]          # shape ~ (captures, samples, 2)

sampling_rate = 2.9e6                     # <-- set correctly
fLO = 1420.115e6                          # <-- if you want RF axis later (optional)

# Choose how many captures to average
M = min(50, indexdata.shape[0])           # try 50 to start

# Use the same N for every FFT
N = indexdata.shape[1]

# Window (and a normalization so power scale is consistent)
window = np.hanning(N)
W2 = np.mean(window**2)                   # window power normalization

P_accum = np.zeros(N, dtype=np.float64)

for m in range(M):
    data = indexdata[m]                   # (N,2)
    x = data[:,0] + 1j*data[:,1]          # complex IQ

    # Remove DC offset (helps a lot)
    x = x - np.mean(x)

    # FFT
    X = np.fft.fftshift(np.fft.fft(x * window))
    P = (np.abs(X)**2) / (N**2 * W2)      # linear power, normalized

    P_accum += P

P_avg = P_accum / M

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))  # Hz

# Convert to dB only at the end (add epsilon to avoid -inf)
P_avg_db = 10*np.log10(P_avg + 1e-20)

# Plotting 
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg, color="teal")
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# Plotting avg. power NO DB
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg_db, color="darkorchid")
# plt.plot(f/1e3, P_avg_db)
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# %%
# Xavi Spectrum 4, increasing blocks to 100 

# Testing OFF-LINE POWER VS IF FREQUENCY PT 2 ELECTRIC BOOGALOO

import numpy as np
import matplotlib.pyplot as plt

importdata = np.load("xavi_spectrum4.npz")
indexdata  = importdata["arr_1"]          # shape ~ (captures, samples, 2)

sampling_rate = 2.9e6                     # <-- set correctly
fLO = 1420.115e6                          # <-- if you want RF axis later (optional)

# Choose how many captures to average
M = min(50, indexdata.shape[0])           # try 50 to start

# Use the same N for every FFT
N = indexdata.shape[1]

# Window (and a normalization so power scale is consistent)
window = np.hanning(N)
W2 = np.mean(window**2)                   # window power normalization

P_accum = np.zeros(N, dtype=np.float64)

for m in range(M):
    data = indexdata[m]                   # (N,2)
    x = data[:,0] + 1j*data[:,1]          # complex IQ

    # Remove DC offset (helps a lot)
    x = x - np.mean(x)

    # FFT
    X = np.fft.fftshift(np.fft.fft(x * window))
    P = (np.abs(X)**2) / (N**2 * W2)      # linear power, normalized

    P_accum += P

P_avg = P_accum / M

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))  # Hz

# Convert to dB only at the end (add epsilon to avoid -inf)
P_avg_db = 10*np.log10(P_avg + 1e-20)

# Plotting 
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg, color="teal")
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# Plotting avg. power NO DB
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg_db, color="darkorchid")
# plt.plot(f/1e3, P_avg_db)
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# %%
# Xavi Spectrum 5, increasing blocks to 1000 

# Testing OFF-LINE POWER VS IF FREQUENCY PT 2 ELECTRIC BOOGALOO

import numpy as np
import matplotlib.pyplot as plt

importdata = np.load("xavi_spectrum5.npz")
indexdata  = importdata["arr_1"]          # shape ~ (captures, samples, 2)

sampling_rate = 2.9e6                     # <-- set correctly
fLO = 1420.115e6                          # <-- if you want RF axis later (optional)

# Choose how many captures to average
M = min(100, indexdata.shape[0])           # try 50 to start

# Use the same N for every FFT
N = indexdata.shape[1]

# Window (and a normalization so power scale is consistent)
window = np.hanning(N)
W2 = np.mean(window**2)                   # window power normalization

P_accum = np.zeros(N, dtype=np.float64)

for m in range(M):
    data = indexdata[m]                   # (N,2)
    x = data[:,0] + 1j*data[:,1]          # complex IQ

    # Remove DC offset (helps a lot)
    x = x - np.mean(x)

    # FFT
    X = np.fft.fftshift(np.fft.fft(x * window))
    P = (np.abs(X)**2) / (N**2 * W2)      # linear power, normalized

    P_accum += P

P_avg = P_accum / M

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))  # Hz

# Convert to dB only at the end (add epsilon to avoid -inf)
P_avg_db = 10*np.log10(P_avg + 1e-20)

# Plotting 
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg, color="teal")
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# Plotting avg. power NO DB
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg_db, color="darkorchid")
# plt.plot(f/1e3, P_avg_db)
plt.xlabel("Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# %%
# Huge, looks good.

# %%
import astropy.units as u
from astropy.coordinates import SkyCoord, EarthLocation, AltAz
from astropy.time import Time

def to_AA(long, lat):
    """
    Convert Galactic lon/lat (l, b) in degrees to (Altitude, Azimuth)
    for an observer in Berkeley.
    """

    # Galactic coordinates (attach units!)
    l = long * u.deg
    b = lat  * u.deg

    # Build Galactic SkyCoord (use l, not a unitless 1)
    coord_gal = SkyCoord(l=l, b=b, frame="galactic")
    coord_icrs = coord_gal.icrs

    # Observer location (Berkeley)
    location = EarthLocation(lat=37.87*u.deg, lon=-122.27*u.deg, height=0*u.m)

    # Observation time (ISO is safest)
    t = Time("2026-02-18 11:31:00", scale="utc")

    # Convert to AltAz
    altaz = coord_icrs.transform_to(AltAz(obstime=t, location=location))

    return f"Altitude:{altaz.alt}, Azimuth:{altaz.az}"

# %%
to_AA(0, 0)
# Out:
# 'Altitude:-2.1282406613134808 deg, Azimuth:125.77764427351352 deg'

# %%
# Actual alt/az were: 125deg, -47deg from zenith

# %%
# Xavi Spectrum 5, increasing blocks to 1000 

# Testing OFF-LINE POWER VS IF FREQUENCY PT 2 ELECTRIC BOOGALOO

import numpy as np
import matplotlib.pyplot as plt

importdata = np.load("milkywaycenter_test1.npz")
indexdata  = importdata["arr_1"]          # shape ~ (captures, samples, 2)

sampling_rate = 2.9e6                     # <-- set correctly
fLO = 1420.115e6                          # <-- if you want RF axis later (optional)

# Choose how many captures to average
M = min(1000, indexdata.shape[0])           # try 50 to start

# Use the same N for every FFT
N = indexdata.shape[1]

# Window (and a normalization so power scale is consistent)
window = np.hanning(N)
W2 = np.mean(window**2)                   # window power normalization

P_accum = np.zeros(N, dtype=np.float64)

for m in range(M):
    data = indexdata[m]                   # (N,2)
    x = data[:,0] + 1j*data[:,1]          # complex IQ

    # Remove DC offset (helps a lot)
    x = x - np.mean(x)

    # FFT
    X = np.fft.fftshift(np.fft.fft(x * window))
    P = (np.abs(X)**2) / (N**2 * W2)      # linear power, normalized

    P_accum += P

P_avg = P_accum / M

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))  # Hz

# Convert to dB only at the end (add epsilon to avoid -inf)
P_avg_db = 10*np.log10(P_avg + 1e-20)



# Plotting 
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg, color="teal")
# plt.axvline(x=10, linestyle=":", color="black")
plt.xlabel("Baseband IF Frequency Offset (kHz)")
plt.ylabel("Power")
#plt.xlim(-500,500)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# Plotting avg. power NO DB
plt.figure(figsize=(10,4))
plt.plot(f/1e3, P_avg_db, color="darkorchid")
# plt.axvline(x=-10, linestyle=":", color="black")
# plt.plot(f/1e3, P_avg_db)
plt.xlabel("Baseband IF Frequency Offset (kHz)")
plt.ylabel("Power (dB)")
# plt.xlim(-250,0)
plt.title(f"Averaged Baseband Power Spectrum (M={M})")
plt.grid(True)
plt.show()

# %%
# NICE PLOTS FOR LAB 2 WEEK 1 PRESENTATION

# %%
# Xavi Spectrum 5, increasing blocks to 1000 


import numpy as np
import matplotlib.pyplot as plt

importdata = np.load("xavi_spectrum5.npz")
indexdata  = importdata["arr_1"]          # shape ~ (captures, samples, 2)

sampling_rate = 2.9e6                     # <-- set correctly
fLO = 1420.115e6                          # <-- if you want RF axis later (optional)

# Choose how many captures to average
M = min(100, indexdata.shape[0])           # try 50 to start

# Use the same N for every FFT
N = indexdata.shape[1]

# Window (and a normalization so power scale is consistent)
window = np.hanning(N)
W2 = np.mean(window**2)                   # window power normalization

P_accum = np.zeros(N, dtype=np.float64)

for m in range(M):
    data = indexdata[m]                   # (N,2)
    x = data[:,0] + 1j*data[:,1]          # complex IQ

    # Remove DC offset (helps a lot)
    x = x - np.mean(x)

    # FFT
    X = np.fft.fftshift(np.fft.fft(x * window))
    P = (np.abs(X)**2) / (N**2 * W2)      # linear power, normalized

    P_accum += P

P_avg = P_accum / M

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))  # Hz

# Convert to dB only at the end (add epsilon to avoid -inf)
P_avg_db = 10*np.log10(P_avg + 1e-20)

# Plotting 

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(10,8), sharex=True)

# First Plot
ax1.plot(f/1e3, P_avg, color="teal")
ax1.set_xlabel("Baseband IF Frequency Offset (kHz)")
ax1.set_ylabel("Power")
ax1.set_title(f"Averaged Baseband Power Spectrum for Ideal Blackbody (Blocks={M})")
ax1.grid(True)

# Second Plot 
ax2.plot(f/1e3, P_avg_db, color="darkorchid")
ax2.set_xlabel("Baseband IF Frequency Offset (kHz)")
ax2.set_ylabel("Power (dB)")
ax2.set_title(f"Averaged Baseband Power Spectrum for Ideal Blackbody (Blocks={M})")
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
# Milky Way 21-cm Line TEST 1


import numpy as np
import matplotlib.pyplot as plt

importdata = np.load("milkywaycenter_test1.npz")
indexdata  = importdata["arr_1"]          # shape ~ (captures, samples, 2)

sampling_rate = 2.9e6                     # <-- set correctly
fLO = 1420.115e6                          # <-- if you want RF axis later (optional)

# Choose how many captures to average
M = min(1000, indexdata.shape[0])           # try 50 to start

# Use the same N for every FFT
N = indexdata.shape[1]

# Window (and a normalization so power scale is consistent)
window = np.hanning(N)
W2 = np.mean(window**2)                   # window power normalization

P_accum = np.zeros(N, dtype=np.float64)

for m in range(M):
    data = indexdata[m]                   # (N,2)
    x = data[:,0] + 1j*data[:,1]          # complex IQ

    # Remove DC offset (helps a lot)
    x = x - np.mean(x)

    # FFT
    X = np.fft.fftshift(np.fft.fft(x * window))
    P = (np.abs(X)**2) / (N**2 * W2)      # linear power, normalized

    P_accum += P

P_avg = P_accum / M

# Frequency axis (baseband)
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/sampling_rate))  # Hz

# Convert to dB only at the end (add epsilon to avoid -inf)
P_avg_db = 10*np.log10(P_avg + 1e-20)



# Plotting 

fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(10,8), sharex=True)

# First Plot
ax1.plot(f/1e3, P_avg, color="teal")
ax1.set_xlabel("Baseband IF Frequency Offset (kHz)")
ax1.set_ylabel("Power")
ax1.set_title(f"Averaged Baseband Power Spectrum (Blocks={M})")
ax1.grid(True)

# Second Plot 
ax2.plot(f/1e3, P_avg_db, color="darkorchid")
ax2.set_xlabel("Baseband IF Frequency Offset (kHz)")
ax2.set_ylabel("Power (dB)")
ax2.set_title(f"Averaged Baseband Power Spectrum (Blocks={M})")
ax2.grid(True)

plt.tight_layout()
plt.show()
