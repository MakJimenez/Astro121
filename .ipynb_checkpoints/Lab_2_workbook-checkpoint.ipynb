# %%
# Importing packages :D

import ugradio
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Advice from the lab instructions:
#     1. Save all metadata necessary to reconstruct observations
#     2. Verify that rotation matricies yield correct pointings and that gain calibration is accurat.
#     Build confidence through internal consistency checks.
#     3. Think critically about assumptions and approximatinos. How do pointing accuracy and aperture coverage
#     affect your calibration? Critically analyze these and other factors in your report.
#     4. Error bars. Error matters. Anything without error doesn't mean shit.

# %% [markdown]
# ### Lab goals:
#     1. Time: Accurate conversion between UTC, PST, LST, and JD.
#     2. Pointing: Use rotation matricies to convert among spherical coordinate systems.
#     3. Measurement: Measure the 21-cm line power spectrum from Milky Way hydrogen at a defined location.
#     4. Calibration: Calibrate observations to an absolute scale, remove systematic instrumental effects, and
#     apply noise-reduction techniques.
#     5. Doppler Correction: Produce spectra with velocities calibrated relative to a standard reference frame.
#     6. Fitting: Fit spectra with Gaussian components to localize celestial structures.
#     7. Impedance: Terminate transmission lines to minimize reflections.
#     8. Propagation: Derive propagation velocities for radio waves in coaxial cables.
#     9. Error Analysis: Use linear and non-linear least-squares methods to fit models and estimate errors.

# %%
# Useful time measurements found in lab mixer 

local_now = ugradio.timing.local_time() # current local time string
ut_now = ugradio.timing.utc()           # current UTC string
un_now = ugradio.timing.unix_time()     # seconds since 1 January 1970
jd_now = ugradio.timing.julian_date()   # current JD
lst_now = ugradio.timing.lst()          # current LST at NCH
# lst_jd = ugradio.timing.lst(jd)         # LST for specified JD 
# ut_jd = ugradio.timing.unix_time(jd)    # s since 1/1/1970 for given JD
# jd_ut = ugradio.timing.julian_date(ut)  # JD for given unix time

# %%
local_now
un_now
# Out:
# 1770950216.0334332

# %%
# Need to set the sample rate correctly and use USB-C cables to collect data through RPi without losing any samples

# %%
birdie3 = np.load("birdietest3_1420.405.npz")

bird3 = birdie3["arr_1"]


# Manipulating data
fs = 3.2e6
N = 2048
shifted_bird = np.fft.fftshift(np.fft.fft(bird3[5]))
power = np.abs(shifted_bird) ** 2

f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))

# Plotting data
plt.figure()
plt.plot(f, 10*np.log10(power)) # converting x axis to khz and y axis to dB instead of dBm
plt.xlim(-0.5, 0.5)
plt.xlabel("Frequency in MHz")
plt.ylabel("Power")
plt.show()
# Out:
# /tmp/ipykernel_3997/3941340091.py:16: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(f, 10*np.log10(power)) # converting x axis to khz and y axis to dB instead of dBm

# %%
# Expecting to see peaks around 185 and 290 kHz, but nothing is seen.

# %%
birdie5 = np.load("birdietest5_1420.405.npz")

bird5 = birdie5["arr_1"]


# Manipulating data
fs = 3.2e6
N = 2048
shifted_bird = np.fft.fftshift(np.fft.fft(bird5[5]))
power = np.abs(shifted_bird) ** 2

f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))

# Plotting data
plt.figure()
plt.plot(f, 10*np.log10(power)) # converting y axis to dB instead of dBm
# plt.xlim(1415, 1425)
plt.xlabel("Frequency in MHz")
plt.ylabel("Power")
plt.show()
# Out:
# /tmp/ipykernel_3997/2853621095.py:16: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(f, 10*np.log10(power)) # converting y axis to dB instead of dBm

# %%
# Quick FT Power Plot
birdie5 = np.load("birdietest5_1420.405.npz")

bird5 = birdie5["arr_1"]

fs = 3.2e6
N = len(bird5[5])

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(bird5[5]))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))

plt.plot(f / 1e3, 10*np.log10(power)) # 1e3 is unit conversion from MHz to kHz
plt.xlim(1400, 1450)
plt.xlabel("Frequency")
plt.ylabel("Power - log scale")
plt.title("Power")
print(plt.show())
# Out:
# /tmp/ipykernel_3997/3197009684.py:14: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(f / 1e3, 10*np.log10(power)) # 1e3 is unit conversion from MHz to kHz
# None

# %%
# Quick FT Power Plot
birdie6 = np.load("birdietest6_1420.405.npz")

bird6 = birdie6["arr_1"]

fs = 3.2e6
N = len(bird6[3])

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(bird6[3]))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))

plt.plot(f / 1e3, 10*np.log10(power)) # 1e3 is unit conversion from MHz to kHz
plt.xlim(1415, 1425)
plt.xlabel("Frequency")
plt.ylabel("Power - log scale")
plt.title("Power")
print(plt.show())
# Out:
# /tmp/ipykernel_3997/3055282815.py:14: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(f / 1e3, 10*np.log10(power)) # 1e3 is unit conversion from MHz to kHz
# None

# %%
# Trying to plot historgram to see Gaussian shape to see clipping

birdie7 = np.load("birdietest7_1420.405.npz")

bird7 = birdie7["arr_1"]

fs = 2.9e6
N = len(bird7[3])

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(bird7[3]))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))

plt.plot(f / 1e3, 10*np.log10(power)) # 1e3 is unit conversion from MHz to kHz
plt.xlim(1415, 1425)
plt.xlabel("Frequency")
plt.ylabel("Power - log scale")
plt.title("Power")
print(plt.show())
birdie7 = np.load("birdietest7_1420.405.npz")

bird7 = birdie7["arr_1"]
# Out:
# /tmp/ipykernel_3997/2890437862.py:15: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(f / 1e3, 10*np.log10(power)) # 1e3 is unit conversion from MHz to kHz
# None

# %%
# Trying to plot historgram to see Gaussian shape to see clipping

birdie7 = np.load("birdietest7_1420.405.npz")

bird7 = birdie7["arr_1"]

# Separate real and imaginary
I = np.real(bird7[3])
Q = np.imag(bird7[3])

# Plotting 

plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
plt.hist(I, bins=100)
plt.xlim(-1.1, -0.9)
plt.title("Histogram of I (real)")
plt.xlabel("ADC Value")
plt.ylabel("Counts")

# Plotting real data
plt.subplot(1, 2, 2)
plt.hist(I, bins=100)
plt.xlim(-1.1, -0.9)
plt.title("Histogram of Q (imag)")
plt.xlabel("ADC Value")
plt.ylabel("Counts")
plt.tight_layout()


plt.show()

# %%
# Made package to quickly plot power spectra
import numpy as np
from quickplot import power
# power.pwr?

power.pwr("birdfreq1420.npz", 3, 2.9e6, xmin=1415 ,xmax=1425 )
# Out:
# ['File:birdfreq1420' 'Frequency:1420 MHz' 'Amplitude:-40 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771274533.0633342'
#  'Local: Mon Feb 16 12:42:13 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Testing 1420 MHz from wave generator, higher amplitude at -40 to get a larger peak in power spectra. Straight SDR to Horn.  ']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3 from quickplot import power
#       4 # power.pwr?
# ----> 6 power.pwr("birdfreq1420.npz", 3, 2.9e6, xmin=1415 ,xmax=1425 )
#
# File ~/Lab_2_Work/Astro121/quickplot/power.py:21, in pwr(data, index, sample_rate, xmin, xmax)
#      18 N = len(indexdata[index])
#      20 plt.figure(figsize=(10,4))
# ---> 21 shifted_ft = np.fft.fftshift(np.fft.fft(bird7[3]))
# ...

# %%
# Plotting power with data from Cable 3

birdie8 = np.load("birdfreq1420.npz")

bird8 = birdie8["arr_1"]

fs = 2.9e6
N = len(bird8[3])

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(bird8[3]))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3 , power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1418, 1422)
plt.yscale("log")
plt.xlabel("Frequency in kHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420 kHz Birdie Signal")
print(plt.show())
# Out:
# None

# %%
# No peak, trying cable 2

# %%
# Plotting power with data from Cable 2

birdie9 = np.load("cable2freq1420.npz")

bird9 = birdie9["arr_1"]
b9 = bird9[3]

fs = 2.9e6
N = len(bird9[3])

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b9))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
plt.yscale("log")
plt.xlabel("Frequency in kHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420 kHz Birdie Signal Cable 2")
print(plt.show())
# Out:
# None

# %%
# Peak very close to 1420, going to move signal to see if that is it. Moving to 1418 kHz

# %%
# Plotting power with data from Cable 2, changing frequency to see if the peak near 1420 is the signal we put there

birdie10 = np.load("cable2freq1418.npz")

bird10 = birdie10["arr_1"]
b10 = bird10[3]

fs = 2.9e6
N = len(bird10[3])

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b10))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1418, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1417, 1419)
plt.yscale("log")
plt.xlabel("Frequency in kHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1418 kHz Birdie Signal Cable 2")
print(plt.show())
# Out:
# None

# %%
# Peak is still slightly above where we are expecting. 
# Also, why are we getting two signals constantly? Something to ask Ben.

# %%
# Plotting power with data from Cable 2
# Increasing amplitude and aiming for 1418 again 

birdie11 = np.load("cable2freq1418_2.npz")

bird11 = birdie11["arr_1"]
b11 = bird11[3]

fs = 2.9e6
N = len(b11)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b11))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1418, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1417, 1419)
plt.yscale("log")
plt.xlabel("Frequency in kHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1418 kHz Birdie Signal Cable 2")
print(plt.show())
# Out:
# None

# %%
# That somehow looks worse, not sure if the amplitude did much. There is a large blue peak there though so...

# %%
# Moving to cable 1. Also just noticed that cable 2 was not plugged in completely
# Cable 1 with freq 1418 and amplitude -10

birdie12 = np.load("cable1freq1418.npz")

bird12 = birdie12["arr_1"]
b12 = bird12[3]

fs = 2.9e6
N = len(b12)
birdfreq1420
plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b12))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1418, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1417, 1419)
plt.yscale("log")
plt.xlabel("Frequency in kHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1418 kHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# None

# %%
# No signal with cable 1, switching back to cable 3

# %%
# Cable 3 with freq 1420.405 and amplitude -80 dBm

birdie13 = np.load("cable3freq1420.405.npz")

bird13 = birdie13["arr_1"]
print(birdie13["arr_0"])
b13 = bird13[3]

fs = 2.9e6
N = len(b13)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b13))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.405, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in kHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.405 kHz Birdie Signal Cable 3")
print(plt.show())
# Out:
# ['File:cable3freq1420.405' 'Frequency:1420.405 MHz' 'Amplitude:-80 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771277338.3204784'
#  'Local: Mon Feb 16 13:28:58 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Testing 1420.405 MHz from wave generator on cable 3, changing amplitude to -80dBm to confirm signal. Straight SDR to Horn.  ']
# None

# %%
# Cable 2 with freq 1420.405 and amplitude -80 dBm

birdie13 = np.load("cable2freq1420.405.npz")

bird13 = birdie13["arr_1"]
print(birdie13["arr_0"])
b13 = bird13[3]

fs = 2.9e6
N = len(b13)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b13))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.405, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in kHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1418 kHz Birdie Signal Cable 2")
print(plt.show())
# Out:
# ['File:cable2freq1420.405' 'Frequency:1420.405 MHz' 'Amplitude:-80 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771277675.3653502'
#  'Local: Mon Feb 16 13:34:35 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Testing 1420.405 MHz from wave generator on cable 2, changing amplitude to -80dBm to confirm signal. Straight SDR to Horn.  ']
# None

# %%
# Cable 1 with freq 1420.405 and amplitude -80 dBm

birdie14 = np.load("cable1freq1420.405.npz")

bird14 = birdie14["arr_1"]
print(birdie14["arr_0"])
b14 = bird14[3]

fs = 2.9e6
N = len(b14)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b14))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.405, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in kHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.405 kHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1freq1420.405' 'Frequency:1420.405 MHz' 'Amplitude:-80 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771278250.4353554'
#  'Local: Mon Feb 16 13:44:10 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Testing 1420.405 MHz from wave generator on cable 1, changing amplitude to -80dBm to confirm signal. Straight SDR to Horn.  ']
# None

# %%
# Slightly off but looking better. Keep freq and increase amplitude.

# %%
# Cable 1 with freq 1420.405 and amplitude -20 dBm

birdie16 = np.load("cable1freq1420.405_2.npz")

bird16 = birdie16["arr_1"]
print(birdie16["arr_0"])
b16 = bird16[3]

fs = 2.9e6
N = len(b16)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b16))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.405, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in kHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.405 kHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1freq1420.405_2' 'Frequency:1420.405 MHz' 'Amplitude:-20 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771278721.1617181'
#  'Local: Mon Feb 16 13:52:01 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Testing 1420.405 MHz from wave generator on cable 1, changing amplitude to -20dBm to confirm signal. Straight SDR to Horn.  ']
# None

# %%
# Why tf is there a sin wave in power

# Cable 3 with freq 1420.405 and amplitude -80 dBm

birdie17 = np.load("cable1freq1420.405_3.npz")

bird17 = birdie17["arr_1"]
print(birdie17["arr_0"])
b17 = bird17[3]

fs = 2.9e6
N = len(b17)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b17))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.405, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.405 MHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1freq1420.405_3' 'Frequency:1420.405 MHz' 'Amplitude:10 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771278923.751599'
#  'Local: Mon Feb 16 13:55:23 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Testing 1420.405 MHz from wave generator on cable 1, changing amplitude to 10 dBm to confirm signal. Straight SDR to Horn.  ']
# None

# %%
# Higher amplitude looks funky as hell. Gonna go back down to -80 dBm because that's what Katie's notes say
# Testing different frequency on cable 1

# %%
# Cable 1 with freq 1420.75 and amplitude -80 dBm

birdie18 = np.load("cable1freq1420.75.npz")

bird18 = birdie18["arr_1"]
print(birdie18["arr_0"])
b18 = bird18[3]

fs = 2.9e6
N = len(b18)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b18))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.75, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.75 MHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1freq1420.75' 'Frequency:1420.75 MHz' 'Amplitude:-80 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771279465.5064456'
#  'Local: Mon Feb 16 14:04:25 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Testing 1420.75 MHz from wave generator on cable 1, changing amplitude to -80 dBm to confirm signal. Straight SDR to Horn.  ']
# None

# %%
# Unplugging cable 1 from the Horn stack on the left of the work bench to see if cable 1 is truly the one sending the LO to the roof
# Error occured, we think it is most likely cable 1 that sends info to the roof. 
# Testing digital gain through sdr.capture_data to see if we can clear up noise on cable 1.

# %%
# Cable 1 with freq 1420.75 and amplitude -80 dBm

birdie19 = np.load("cable1gainfreq1420.75_4.npz")

bird19 = birdie19["arr_1"]
print(birdie19["arr_0"])
b19 = bird19[3]

fs = 2.9e6
N = len(b19)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b19))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.75, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.75 MHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1gainfreq1420.75_4' 'Frequency:1420.75 MHz'
#  'Amplitude:-80 dBm' 'Sampling Rate:2900000.0' 'Direct:False'
#  'Unix: 1771280944.574985' 'Local: Mon Feb 16 14:29:04 2026'
#  'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Apparently the horn was off. Trying again.']
# None

# %%
# Now trying digital gain = 1 dB

birdie20 = np.load("cable1gainfreq1420.75_5.npz")

bird20 = birdie20["arr_1"]
print(birdie20["arr_0"])
b20 = bird20[3]

fs = 2.9e6
N = len(b20)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b20))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.75, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.75 MHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1gainfreq1420.75_5' 'Frequency:1420.75 MHz'
#  'Amplitude:-80 dBm' 'Sampling Rate:2900000.0' 'Direct:False'
#  'Unix: 1771281115.7807975' 'Local: Mon Feb 16 14:31:55 2026'
#  'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Looks normal again, testing gain = 1 dB through SDR again.']
# None

# %%
# Baby peak showing on the correct line. Increasing the gain.

# %%
# Now trying digital gain = 10 dB

birdie21 = np.load("cable1gainfreq1420.75_6.npz")

bird21 = birdie21["arr_1"]
print(birdie21["arr_0"])
b21 = bird21[3]

fs = 2.9e6
N = len(b21)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b21))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.75, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.75 MHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1gainfreq1420.75_6' 'Frequency:1420.75 MHz'
#  'Amplitude:-80 dBm' 'Sampling Rate:2900000.0' 'Direct:False'
#  'Unix: 1771281192.2204163' 'Local: Mon Feb 16 14:33:12 2026'
#  'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Cannot tell from previous results. Testing gain = 10 dB through SDR again.']
# None

# %%
# Even larger peak showing on the correct line, going to increase gain again to confirm signal.

# %%
# Now trying digital gain = 10 dB

birdie22 = np.load("cable1gainfreq1420.75_7.npz")

bird22 = birdie22["arr_1"]
print(birdie22["arr_0"])
b22 = bird22[3]

fs = 2.9e6
N = len(b22)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b22))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.75, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.75 MHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1gainfreq1420.75_7' 'Frequency:1420.75 MHz'
#  'Amplitude:-80 dBm' 'Sampling Rate:2900000.0' 'Direct:False'
#  'Unix: 1771281498.6641653' 'Local: Mon Feb 16 14:38:18 2026'
#  'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Looks like peak is increasing with gain, confirming signal with increased gain. Testing gain = 15 dB through SDR again.']
# None

# %%
# Now trying digital gain = 21 dB

birdie23 = np.load("cable1gainfreq1420.75_8.npz")

bird23 = birdie23["arr_1"]
print(birdie23["arr_0"])
b23 = bird23[3]

fs = 2.9e6
N = len(b23)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b23))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.75, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.75 MHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1gainfreq1420.75_8' 'Frequency:1420.75 MHz'
#  'Amplitude:-80 dBm' 'Sampling Rate:2900000.0' 'Direct:False'
#  'Unix: 1771281667.1140056' 'Local: Mon Feb 16 14:41:07 2026'
#  'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Looks like peak is increasing with gain, confirming signal with increased gain. Testing gain = 21 dB through SDR again.']
# None

# %%
# Too high, signal lost. Going back down.

# %%
# Now trying digital gain = 18 dB

birdie24 = np.load("cable1gainfreq1420.75_9.npz")

bird24 = birdie24["arr_1"]
print(birdie24["arr_0"])
b24 = bird24[3]

fs = 2.9e6
N = len(b24)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b24))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.75, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.75 MHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1gainfreq1420.75_9' 'Frequency:1420.75 MHz'
#  'Amplitude:-80 dBm' 'Sampling Rate:2900000.0' 'Direct:False'
#  'Unix: 1771281828.015823' 'Local: Mon Feb 16 14:43:48 2026'
#  'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Looks like peak is increasing with gain, confirming signal with increased gain. Testing gain = 18 dB through SDR again.']
# None

# %%
# Now trying digital gain = 10 dB again to see if signal comes back. 
 
birdie25 = np.load("cable1gainfreq1420.75_9.npz")

bird25 = birdie25["arr_1"]
print(birdie25["arr_0"])
b25 = bird25[3]

fs = 2.9e6
N = len(b25)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b25))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.75, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.75 MHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1gainfreq1420.75_9' 'Frequency:1420.75 MHz'
#  'Amplitude:-80 dBm' 'Sampling Rate:2900000.0' 'Direct:False'
#  'Unix: 1771281947.2097712' 'Local: Mon Feb 16 14:45:47 2026'
#  'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Lost signal, confirming signal with decreased gain. Testing gain = 10 dB through SDR again.']
# None

# %%
# Signal lost, guessing there is water in the horn. Gonna go empty it :( 
# Horn emptied at 2:55 pm

# %%
# Now trying digital gain = 10 dB again to see if signal comes back. 
 
birdie25 = np.load("cable1gainfreq1420.npz")

bird25 = birdie25["arr_1"]
print(birdie25["arr_0"])
b25 = bird25[3]

fs = 2.9e6
N = len(b25)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b25))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.75, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.75 MHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1gainfreq1420' 'Frequency:1420 MHz' 'Amplitude:-80 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771282590.2838733'
#  'Local: Mon Feb 16 14:56:30 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Testing 10 dB gain again with water emptied.']
# None

# %%
# Now trying digital gain = 10 dB again to see if signal comes back. 
 
birdie25 = np.load("cable1gainfreq1420_2.npz")

bird25 = birdie25["arr_1"]
print(birdie25["arr_0"])
b25 = bird25[3]

fs = 2.9e6
N = len(b25)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b25))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420.75, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.75 MHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1gainfreq1420_2' 'Frequency:1420 MHz' 'Amplitude:-80 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771282639.6021867'
#  'Local: Mon Feb 16 14:57:19 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Looks like small signal, testing higher gain. Testing 15 dB gain again with water emptied.']
# None

# %%
# Signal not confirmed. Adding attenuator before SDR now.

# %%
# Also added 10 dB attenuator before SDR connection.


# Now trying digital gain = 10 dB again to see if signal comes back. 
 
birdie26 = np.load("cable1gainfreq1420_3.npz")

bird26 = birdie26["arr_1"]
print(birdie26["arr_0"])
b26 = bird26[3]

fs = 2.9e6
N = len(b26)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b26))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.75 MHz Birdie Signal Cable 1")
print(plt.show())
# Out:
# ['File:cable1gainfreq1420_3' 'Frequency:1420 MHz' 'Amplitude:-40 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771283159.350715'
#  'Local: Mon Feb 16 15:05:59 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Testing lower gain = 3 dB with higher amplitude at -40 dBm.']
# None

# %%
# Testing different frequency to see if any peaks move. Also increasing gain while keeping amplitude the same.

# %%
# Made package to quickly plot power spectra
import numpy as np
from quickplot import power
# power.pwr?

power.pwr("birdfreq1420.npz", 3, 2.9e6, xmin=1415 ,xmax=1425 )
# Out:
# ['File:birdfreq1420' 'Frequency:1420 MHz' 'Amplitude:-40 dBm'
#  'Sampling Rate:2900000.0' 'Direct:False' 'Unix: 1771274533.0633342'
#  'Local: Mon Feb 16 12:42:13 2026' 'Location: NCH'
#  'Direction: 8th rung from the left, pointing north (aligned with square at bottom), above red roof'
#  'Notes: Testing 1420 MHz from wave generator, higher amplitude at -40 to get a larger peak in power spectra. Straight SDR to Horn.  ']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 6
#       3 from quickplot import power
#       4 # power.pwr?
# ----> 6 power.pwr("birdfreq1420.npz", 3, 2.9e6, xmin=1415 ,xmax=1425 )
#
# File ~/Lab_2_Work/Astro121/quickplot/power.py:21, in pwr(data, index, sample_rate, xmin, xmax)
#      18 N = len(indexdata[index])
#      20 plt.figure(figsize=(10,4))
# ---> 21 shifted_ft = np.fft.fftshift(np.fft.fft(bird7[3]))
# ...

# %%
# Also added 10 dB attenuator before SDR connection.


# Now trying digital gain = 10 dB again to see if signal comes back. 
 
birdie26 = np.load("cable1gainfreq1420_3.npz")

bird26 = birdie26["arr_1"]
print(birdie26["arr_0"])
b26 = bird26[3]

fs = 2.9e6
N = len(b26)

plt.figure(figsize=(10,4))
shifted_ft = np.fft.fftshift(np.fft.fft(b26))
power = np.abs(shifted_ft) ** 2
f = np.fft.fftshift(np.fft.fftfreq(N, d=1/fs))



plt.plot(f / 1e3, power) # 1e3 is unit conversion from MHz to kHz
plt.axvline(x=1420, linestyle=":", color="black", linewidth=2) # reference frequency
plt.xlim(1419, 1421)
# plt.yscale("log")
plt.xlabel("Frequency in MHz")
plt.ylabel("Power - log scale")
plt.title("Power Spectra for 1420.75 MHz Birdie Signal Cable 1")
print(plt.show())
